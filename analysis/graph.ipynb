# %%
import numpy as np 
import matplotlib.pyplot as plt
import os.path

# %%
dir = "C:/Users/lixia/OneDrive/桌面/distiller_lxm/analysis/figures/" 
plt.figure(figsize = [16,5])

# %% [markdown]
# ### Resnet34(Imagenet Pre-trained) agp pruning to correspond sparsity then conduct transfer learning on Cifar10_resize dataset.(224x224)  vs transfering learning with dense model then prune to correspond sparsity

# %%
Sparsity = ['dense', '50%', '70%', '80%', '90%']
Prune1Accuracy = [96.130, 96.580, 96.370, 96.200, 95.780]
Transfer1Accuracy = [96.130, 96.450, 96.610, 96.570, 96.300]
plt.plot(Sparsity, Prune1Accuracy, color='red', marker='o', linestyle='solid', label='P-T')
plt.plot(Sparsity, Transfer1Accuracy, color='blue', marker='o', linestyle='solid',label='T-P')
plt.legend(loc='lower left')
plt.title("Resnet34 pruning and transfer learning on Cifar10")
plt.set_ylabel =("TOP1 Accuracy")
plt.set_xlabel = ("Sparsity")
filename = os.path.join(dir,"Resnet34_Cifar10.png")
plt.savefig(filename, dpi=300)
plt.show()

# %% [markdown]
# ### Resnet34(Imagenet Pre-trained) agp pruning to correspond sparsity then conduct transfer learning on Food101_resize dataset.(224x224) vs transfering learning with dense model then prune to correspond sparsity

# %%
Sparsity = ['dense', '50%', '70%', '80%', '90%']
Prune1Accuracy = [82.178, 82.222, 82.606, 81.406, 81.667]
Transfer1Accuracy = [82.178, 84.891, 84.646, 84.566, 84.150]
plt.ylabel =["TOP1 Accuracy"]
plt.xlabel = ["Sparsity"]
plt.plot(Sparsity, Prune1Accuracy, color='red', marker='o', linestyle='solid', label='P-T')
plt.plot(Sparsity, Transfer1Accuracy, color='blue', marker='o', linestyle='solid',label='T-P')
plt.title("Resnet34 pruning and transfer learning on Food101")
plt.legend(loc='lower left')
filename = os.path.join(dir,"Resnet34_Food101.png")
plt.savefig(filename, dpi=300)
plt.show()

# %% [markdown]
# ### VGG16(Imagenet Pre-trained) agp pruning to correspond sparsity then conduct transfer learning on Cifar10_resize dataset.(224x224)  vs transfering learning with dense model then prune to correspond sparsity

# %%
Sparsity = ['dense', '50%', '70%', '80%', '90%']
Prune1Accuracy = [93.080, 93.300, 93.810, 94.260, 93.330]
Transfer1Accuracy = [93.080, 94.560, 95.070, 94.680, 94.600]
plt.ylabel =["TOP1 Accuracy"]
plt.xlabel = ["Sparsity"]
plt.plot(Sparsity, Prune1Accuracy, color='red', marker='o', linestyle='solid', label='P-T')
plt.plot(Sparsity, Transfer1Accuracy, color='blue', marker='o', linestyle='solid',label='T-P')
plt.title("VGG16 pruning and transfer learning on Cifar10")
plt.legend(loc='upper left')
filename = os.path.join(dir,"VGG16_Cifar10.png")
plt.savefig(filename, dpi=300)
plt.show()

# %% [markdown]
# ### VGG16(Imagenet Pre-trained) agp pruning to correspond sparsity then conduct transfer learning on FOOD100_resize dataset.(224x224)  vs transfering learning with dense model then prune to correspond sparsity

# %%
Sparsity = ['dense', '50%', '70%', '80%', '90%']
Prune1Accuracy = [78.547, 80.602, 80.432, 80.135, 77.085]
Transfer1Accuracy = [78.547, 85.485, 85.750, 85.604, 85.073]
plt.ylabel =["TOP1 Accuracy"]
plt.xlabel = ["Sparsity"]
plt.plot(Sparsity, Prune1Accuracy, color='red', marker='o', linestyle='solid', label='P-T')
plt.plot(Sparsity, Transfer1Accuracy, color='blue', marker='o', linestyle='solid',label='T-P')
plt.title("VGG16 pruning and transfer learning on Food101")
plt.legend(loc='upper left')
filename = os.path.join(dir,"VGG16_Food101.png")
plt.savefig(filename, dpi=300)
plt.show()

# %% [markdown]
# ### Resnet34(Imagenet Pre-trained) agp pruning to correspond sparsity then conduct transfer learning on Cifar10_resize 224x224)  then further prune the model to correspond sparsity

# %%
spa0_trans_prune_spa = ['dense', '50%', '70%', '80%', '90%']
spa0_trans_prune_acc = [96.130, 96.580, 96.370, 96.200, 95.780]
spa50_trans_prune_spa = ['50%', '70%', '80%', '90%']
spa50_trans_prune_acc = [96.580, 96.650, 96.740, 96.500]
spa70_trans_prune_spa = ['70%', '80%', '90%']
spa70_trans_prune_acc = [96.370, 96.610, 96.350]
spa80_trans_prune_spa = ['80%', '90%']
spa90_trans_prune_acc = [96.200, 96.290]

plt.ylabel =["TOP1 Accuracy"]
plt.xlabel = ["Sparsity"]
plt.plot(spa0_trans_prune_spa, spa0_trans_prune_acc, color='red', marker='o', linestyle='solid', label='Init=0%')
plt.plot(spa50_trans_prune_spa, spa50_trans_prune_acc, color='orange', marker='o', linestyle='solid', label='Init=50%')
plt.plot(spa70_trans_prune_spa, spa70_trans_prune_acc, color='green', marker='o', linestyle='solid',label='Init=70%')
plt.plot(spa80_trans_prune_spa, spa90_trans_prune_acc, color='blue', marker='o', linestyle='solid',label='Init=80%')
plt.title("Resnet34 pruning and transfer learning on Cifar10")
plt.legend(loc='lower left')
filename = os.path.join(dir,"Resnet34_PTP_Cifar10.png")
plt.savefig(filename, dpi=300)
plt.show()
